# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/PRATIKSHA/Downloads/Diabetes Simple Diagnosis.csv")

# %%
df
# Out:
#        Unnamed: 0  Age  Gender  BMI  High_BP  FBS  HbA1c_level  Smoking  \
# 0               0   80  Female   25        0  140          6.6        0
# 1               1   54  Female   27        0   80          6.6        0
# 2               2   28    Male   27        0  158          5.7        0
# 3               3   36  Female   23        0  155          5.0        1
# 4               4   76    Male   20        1  155          4.8        1
# ...           ...  ...     ...  ...      ...  ...          ...      ...
# 88375       88375   17  Female   15        0  100          5.7        1
# 88376       88376   22    Male   19        0  120          6.4        1
# 88377       88377   27  Female   24        1  140          7.1        1
# 88378       88378   32    Male   29        1  160          7.8        1
# 88379       88379   37  Female   34        1  180          8.5        1
#
#        Diagnosis
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 88375          1
# 88376          1
# 88377          1
# 88378          1
# 88379          1
#
# [88380 rows x 9 columns]

# %%
df.shape
# Out:
# (88380, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88380 entries, 0 to 88379
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   88380 non-null  int64
#  1   Age          88380 non-null  int64
#  2   Gender       88380 non-null  object
#  3   BMI          88380 non-null  int64
#  4   High_BP      88380 non-null  int64
#  5   FBS          88380 non-null  int64
#  6   HbA1c_level  88380 non-null  float64
#  7   Smoking      88380 non-null  int64
#  8   Diagnosis    88380 non-null  int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 6.1+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Age            0
# Gender         0
# BMI            0
# High_BP        0
# FBS            0
# HbA1c_level    0
# Smoking        0
# Diagnosis      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#          Unnamed: 0           Age           BMI       High_BP           FBS  \
# count  88380.000000  88380.000000  88380.000000  88380.000000  88380.000000
# mean   44189.500000     42.124010     27.073999      0.084205    138.662197
# std    25513.252733     22.281225      6.923608      0.277696     41.378602
# min        0.000000      0.000000     10.000000      0.000000     80.000000
# 25%    22094.750000     24.000000     23.000000      0.000000    100.000000
# 50%    44189.500000     43.000000     27.000000      0.000000    140.000000
# 75%    66284.250000     60.000000     30.000000      0.000000    159.000000
# max    88379.000000     80.000000     95.000000      1.000000    300.000000
#
#         HbA1c_level       Smoking     Diagnosis
# count  88380.000000  88380.000000  88380.000000
# mean       5.546687      0.313419      0.095316
# std        1.085351      0.463886      0.293652
# min        3.500000      0.000000      0.000000
# 25%        4.800000      0.000000      0.000000
# 50%        5.800000      0.000000      0.000000
# 75%        6.200000      1.000000      0.000000
# max       12.000000      1.000000      1.000000

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#        Age  Gender  BMI  High_BP  FBS  HbA1c_level  Smoking  Diagnosis
# 0       80  Female   25        0  140          6.6        0          0
# 1       54  Female   27        0   80          6.6        0          0
# 2       28    Male   27        0  158          5.7        0          0
# 3       36  Female   23        0  155          5.0        1          0
# 4       76    Male   20        1  155          4.8        1          0
# ...    ...     ...  ...      ...  ...          ...      ...        ...
# 88375   17  Female   15        0  100          5.7        1          1
# 88376   22    Male   19        0  120          6.4        1          1
# 88377   27  Female   24        1  140          7.1        1          1
# 88378   32    Male   29        1  160          7.8        1          1
# 88379   37  Female   34        1  180          8.5        1          1
#
# [88380 rows x 8 columns]

# %%
sns.countplot(x='Diagnosis',data=df)
# Out:
# <Axes: xlabel='Diagnosis', ylabel='count'>

# %%
# plt.figure(figsize=(12, 8))
# sns.histplot(data=df, x='Age',hue='Diagnosis', multiple='stack', bins=20)
# plt.title('Distribution of Age by Diagnosis')
# plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df['Gender']=l.fit_transform(df['Gender'])

# %%
df
# Out:
#        Age  Gender  BMI  High_BP  FBS  HbA1c_level  Smoking  Diagnosis
# 0       80       0   25        0  140          6.6        0          0
# 1       54       0   27        0   80          6.6        0          0
# 2       28       1   27        0  158          5.7        0          0
# 3       36       0   23        0  155          5.0        1          0
# 4       76       1   20        1  155          4.8        1          0
# ...    ...     ...  ...      ...  ...          ...      ...        ...
# 88375   17       0   15        0  100          5.7        1          1
# 88376   22       1   19        0  120          6.4        1          1
# 88377   27       0   24        1  140          7.1        1          1
# 88378   32       1   29        1  160          7.8        1          1
# 88379   37       0   34        1  180          8.5        1          1
#
# [88380 rows x 8 columns]

# %%
x=df.drop('Diagnosis',axis=1)
x
# Out:
#        Age  Gender  BMI  High_BP  FBS  HbA1c_level  Smoking
# 0       80       0   25        0  140          6.6        0
# 1       54       0   27        0   80          6.6        0
# 2       28       1   27        0  158          5.7        0
# 3       36       0   23        0  155          5.0        1
# 4       76       1   20        1  155          4.8        1
# ...    ...     ...  ...      ...  ...          ...      ...
# 88375   17       0   15        0  100          5.7        1
# 88376   22       1   19        0  120          6.4        1
# 88377   27       0   24        1  140          7.1        1
# 88378   32       1   29        1  160          7.8        1
# 88379   37       0   34        1  180          8.5        1
#
# [88380 rows x 7 columns]

# %%
y=df['Diagnosis']
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 88375    1
# 88376    1
# 88377    1
# 88378    1
# 88379    1
# Name: Diagnosis, Length: 88380, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#        Age  Gender  BMI  High_BP  FBS  HbA1c_level  Smoking
# 88271   40       0   30        1  140          7.1        0
# 52139    5       1   16        0  160          4.5        0
# 25766   10       1   25        0   85          5.7        0
# 11067   44       0   29        0  200          6.5        0
# 62827    4       0   17        0  126          5.7        0
# ...    ...     ...  ...      ...  ...          ...      ...
# 21243   60       0   19        0   90          4.8        1
# 45891   32       0   32        0  100          5.8        0
# 42613    8       1   21        0  130          4.0        0
# 43567   20       0   27        0  158          4.8        0
# 68268   27       0   37        0  160          4.8        1
#
# [70704 rows x 7 columns]

# %%
x_test
# Out:
#        Age  Gender  BMI  High_BP  FBS  HbA1c_level  Smoking
# 75077   28       0   35        0  155          6.5        0
# 77124   55       0   27        0  130          3.5        0
# 45990   45       0   48        0  160          6.5        0
# 8845    44       1   29        0  200          4.5        0
# 10258   45       1   24        0   90          4.8        0
# ...    ...     ...  ...      ...  ...          ...      ...
# 5072    32       0   37        0   90          6.0        0
# 63186   59       0   20        0  100          6.0        0
# 16927   25       1   24        0  130          5.7        0
# 29299   31       0   27        0   90          5.0        1
# 46984   13       0   27        0  158          6.0        0
#
# [17676 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.09441669, -0.8507738 ,  0.42489754, ...,  0.0372473 ,
#          1.43320336, -0.67582035],
#        [-1.66345674,  1.17362919, -1.5995612 , ...,  0.52113475,
#         -0.96360994, -0.67582035],
#        [-1.43930816,  1.17362919, -0.29812344, ..., -1.29344318,
#          0.14261158, -0.67582035],
#        ...,
#        [-1.52896759,  1.17362919, -0.87654022, ..., -0.20469642,
#         -1.42453558, -0.67582035],
#        [-0.991011  , -0.8507738 , -0.00891505, ...,  0.47274601,
#         -0.68705456, -0.67582035],
#        [-0.67720299, -0.8507738 ,  1.43712691, ...,  0.52113475,
#         -0.68705456,  1.47968317]])

# %%
x_test.shape
# Out:
# (17676, 7)

# %%
from sklearn.linear_model import LogisticRegression
lr =LogisticRegression(random_state=0)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[15816,   140],
#        [  660,  1060]], dtype=int64)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.9547408916044354

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     15956
#            1       0.88      0.62      0.73      1720
#
#     accuracy                           0.95     17676
#    macro avg       0.92      0.80      0.85     17676
# weighted avg       0.95      0.95      0.95     17676

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize and train the Decision Tree model
dt = DecisionTreeClassifier(max_depth=3,random_state=0)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(30,10))
tree.plot_tree(dt,filled=True)
# Out:
# [Text(0.5555555555555556, 0.875, 'x[5] <= 1.064\ngini = 0.172\nsamples = 70704\nvalue = [64000, 6704]'),
#  Text(0.3333333333333333, 0.625, 'x[4] <= 1.731\ngini = 0.102\nsamples = 67575\nvalue = [63949, 3626]'),
#  Text(0.2222222222222222, 0.375, 'x[0] <= 0.511\ngini = 0.065\nsamples = 66187\nvalue = [63949, 2238]'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.028\nsamples = 45132\nvalue = [44494, 638]'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.14\nsamples = 21055\nvalue = [19455.0, 1600.0]'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.0\nsamples = 1388\nvalue = [0, 1388]'),
#  Text(0.7777777777777778, 0.625, 'x[5] <= 3.277\ngini = 0.032\nsamples = 3129\nvalue = [51, 3078]'),
#  Text(0.6666666666666666, 0.375, 'x[0] <= 0.062\ngini = 0.012\nsamples = 3097\nvalue = [19, 3078]'),
#  Text(0.5555555555555556, 0.125, 'gini = 0.071\nsamples = 381\nvalue = [14, 367]'),
#  Text(0.7777777777777778, 0.125, 'gini = 0.004\nsamples = 2716\nvalue = [5, 2711]'),
#  Text(0.8888888888888888, 0.375, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]')]

# %%
# Make predictions
y_pred_dt = dt.predict(x_test)

# %%
# Evaluate the Decision Tree model
acc = accuracy_score(y_test, y_pred_dt)
acc
# Out:
# 0.9679226069246436

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     15956
#            1       0.99      0.67      0.80      1720
#
#     accuracy                           0.97     17676
#    macro avg       0.98      0.84      0.89     17676
# weighted avg       0.97      0.97      0.97     17676

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=10, random_state=0)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=0)

# %%
y_pred_rf = rf.predict(x_test)
y_pred_rf
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
acc = accuracy_score(y_test, y_pred_rf)
acc
# Out:
# 0.9639058610545372
